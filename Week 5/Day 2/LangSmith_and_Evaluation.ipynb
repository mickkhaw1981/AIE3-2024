# %% [markdown]
# # LangSmith and Evaluation Overview with AI Makerspace
#
# Today we'll be looking at an amazing tool:
#
# [LangSmith](https://docs.smith.langchain.com/)!
#
# This tool will help us monitor, test, debug, and evaluate our LangChain applications - and more!
#
# We'll also be looking at a few Advanced Retrieval techniques along the way - and evaluate it using LangSmith!
#
# ✋BREAKOUT ROOM #1:
# - Task 1: Dependencies and OpenAI API Key
# - Task 2: Basic RAG Chain
# - Task 3: Setting Up LangSmith
# - Task 4: Examining the Trace in LangSmith!
# - Task 5: Create Testing Dataset
#
# ✋BREAKOUT ROOM #2:
# - Task 1: Parent Document Retriever
# - Task 2: Ensemble Retriever

# %% [markdown]
# ## Task 1: Dependencies and OpenAI API Key
#
# We'll be using OpenAI's suite of models today to help us generate and embed our documents for a simple RAG system built on top of LangChain's blogs!

# %%
# !pip install langchain_core langchain_openai langchain_community langchain-qdrant qdrant-client langsmith openai tiktoken cohere lxml -qU

# %%
import os
import getpass

os.environ["OPENAI_API_KEY"] = getpass.getpass("Enter your OpenAI API Key:")

# %% [markdown]
# ## Task 2: Basic RAG Chain
#
# Now we'll set up our basic RAG chain, first up we need a model!

# %% [markdown]
# ### OpenAI Model
#
#
# We'll use OpenAI's `gpt-3.5-turbo` model to ensure we can use a stronger model for decent evaluation later!
#
# Notice that we can tag our resources - this will help us be able to keep track of which resources were used where later on!

# %%
from langchain_openai.chat_models import ChatOpenAI

base_llm = ChatOpenAI(model="gpt-3.5-turbo", tags=["base_llm"])

# %% [markdown]
# #### Asyncio Bug Handling
#
# This is necessary for Colab.

# %%
import nest_asyncio
nest_asyncio.apply()

# %% [markdown]
# ### SiteMap Loader
#
# We'll use a SiteMapLoader to scrape the LangChain blogs.

# %%
from langchain.document_loaders import SitemapLoader

documents = SitemapLoader(web_path="https://blog.langchain.dev/sitemap-posts.xml").load()
# Out:
# Fetching pages: 100%|##########| 219/219 [00:11<00:00, 19.47it/s]

# %%
documents[0].metadata["source"]
# Out:
# 'https://blog.langchain.dev/langgraph-cloud/'

# %% [markdown]
# ### RecursiveCharacterTextSplitter
#
# We're going to use a relatively naive text splitting strategy today!

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

split_documents = RecursiveCharacterTextSplitter.from_tiktoken_encoder(
    chunk_size = 500,
    chunk_overlap = 20
).split_documents(documents)

# %%
len(split_documents)
# Out:
# 1536

# %% [markdown]
# ### Embeddings
#
# We'll be leveraging OpenAI's [text-embedding-3-small](https://openai.com/index/new-embedding-models-and-api-updates/) today!

# %%
from langchain_openai.embeddings import OpenAIEmbeddings

base_embeddings_model = OpenAIEmbeddings(model="text-embedding-3-small")

# %% [markdown]
# ### Qdrant VectorStore Retriever
#
# Now we can use a Qdrant VectorStore to embed and store our documents and then convert it to a retriever so it can be used in our chain!

# %%
from langchain_qdrant import Qdrant

vectorstore = Qdrant.from_documents(
    split_documents,
    base_embeddings_model,
    location=":memory:",
    collection_name="langchainblogs")

# %%
base_retriever = vectorstore.as_retriever()

# %% [markdown]
# ### Prompt Template
#
# All we have left is a prompt template, which we'll create here!

# %%
from langchain.prompts import ChatPromptTemplate

base_rag_prompt_template = """\
Using the provided context, please answer the user's question. If you don't know the answer based on the context, say you don't know.

Context:
{context}

Question:
{question}
"""

base_rag_prompt = ChatPromptTemplate.from_template(base_rag_prompt_template)

# %% [markdown]
# ### LCEL Chain
#
# Now that we have:
#
# - Embeddings Model
# - Generation Model
# - Retriever
# - Prompt
#
# We're ready to build our LCEL chain!
#
# Keep in mind that we're returning our source documents with our queries - while this isn't necessary, it's a great thing to get into the habit of doing.

# %%
from operator import itemgetter
from langchain_core.runnables import RunnablePassthrough, RunnableParallel
from langchain.schema import StrOutputParser

base_rag_chain = (
    # INVOKE CHAIN WITH: {"question" : "<<SOME USER QUESTION>>"}
    # "question" : populated by getting the value of the "question" key
    # "context"  : populated by getting the value of the "question" key and chaining it into the base_retriever
    {"context": itemgetter("question") | base_retriever, "question": itemgetter("question")}
    # "context"  : is assigned to a RunnablePassthrough object (will not be called or considered in the next step)
    #              by getting the value of the "context" key from the previous step
    | RunnablePassthrough.assign(context=itemgetter("context"))
    # "response" : the "context" and "question" values are used to format our prompt object and then piped
    #              into the LLM and stored in a key called "response"
    # "context"  : populated by getting the value of the "context" key from the previous step
    | {"response": base_rag_prompt | base_llm | StrOutputParser(), "context": itemgetter("context")}
)

# %% [markdown]
# Let's test it out!

# %%
base_rag_chain.invoke({"question" : "What is a good way to evaluate agents?"})["response"]
# Out:
# "A good way to evaluate agents is to test their capabilities in tasks related to planning, task decomposition, function calling, and the ability to override pre-trained biases when needed. This can help determine an agent's effectiveness and reliability in performing various workflows that require reasoning."

# %% [markdown]
# ## Task 3: Setting Up LangSmith
#
# Now that we have a chain - we're ready to get started with LangSmith!
#
# We're going to go ahead and use the following `env` variables to get our Colab notebook set up to start reporting.
#
# If all you needed was simple monitoring - this is all you would need to do!

# %%
from uuid import uuid4

unique_id = uuid4().hex[0:8]

os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_PROJECT"] = f"LangSmith - {unique_id}"

# %% [markdown]
# ### LangSmith API
#
# In order to use LangSmith - you will need a beta key, you can join the queue through the `Beta Sign Up` button on LangSmith's homepage!
#
# Join [here](https://www.langchain.com/langsmith)

# %%
os.environ["LANGCHAIN_API_KEY"] = getpass.getpass('Enter your LangSmith API key: ')

# %% [markdown]
# Let's test our our first generation!

# %%
base_rag_chain.invoke({"question" : "What is LangSmith?"}, {"tags" : ["Demo Run"]})['response']
# Out:
# 'LangSmith is a unified platform for debugging, testing, evaluating, and monitoring LLM (Large Language Model) applications. It allows users to easily debug, monitor, test, evaluate, and share their LLM applications.'

# %% [markdown]
# ## Task 4: Examining the Trace in LangSmith!
#
# Head on over to your LangSmith web UI to check out how the trace looks in LangSmith!

# %% [markdown]
# #### 🏗️ Activity #1:
#
# Include a screenshot of your trace and explain what it means.

# %% [markdown]
# **ANSWER:**
#
# Screenshot: https://capture.dropbox.com/zNsAX9zJfu8lcdGW
#
# RunnableSequence: This is the overall execution flow, which took 1.53s and used 1,840 tokens.
#
# The sequence consists of two main steps:
#
# a. map:key:context (0.39s): This step appears to retrieve relevant context documents based on the input, using the Retriever
#
# b. map:key:response (1.10s): This step generates the final output based on the RAG prompt (context + user input), using ChatOpenAI API call to GPT-3.5-turbo model

# %% [markdown]
# ## Task 5: Create Testing Dataset
#
# Now we can create a dataset using some user defined questions, and providing the retrieved context as a "ground truth" context.
#
# > NOTE: There are many different ways you can approach this specific task - generating ground truth answers with AI, using human experts to generate golden datasets, and more!

# %% [markdown]
# ### Synthetic Data Generation (SDG)
#
# In order to full test our RAG chain, and the various modifications we'll be using in the following notebook, we'll need to create a small synthetic dataset that is relevant to our task!
#
# Let's start by generating a series of questions - which begins with a simple model definition!
#
# > NOTE: We're going to be using a purposefully simplified datagen pipeline as an example today - but you could leverage the RAGAS SDG pipeline just as easily.

# %%
question_model = ChatOpenAI(model="gpt-4o")

# %% [markdown]
# Next up, we'll create some novel chunks from our source data!

# %%
sdg_documents = RecursiveCharacterTextSplitter.from_tiktoken_encoder(
    chunk_size = 1000,
    chunk_overlap = 20
).split_documents(documents)

# %% [markdown]
# Now, let's ask some questions that could be answered from the provided chunks!

# %%
question_prompt_template = """\
You are a University Professor creating questions for an exam. You must create a question for a given piece of context.

The question must be answerable only using the provided context.

Avoid creating questions that are ambiguous or vague. They should be specifically related to the context.

Your output must only be the question.

Context:
{context}
"""

question_prompt = ChatPromptTemplate.from_template(question_prompt_template)

# %%
question_chain = question_prompt | question_model

# %% [markdown]
# Now we can loop through a subset of our context chunks and create question/context pairs!

# %%
from tqdm import tqdm
import json

question_context_pairs = []

for idx in tqdm(range(0, len(sdg_documents), 40)):
  question = question_chain.invoke({"context" : sdg_documents[idx].page_content})
  question_context_pairs.append({"question" : question.content, "context" : sdg_documents[idx].page_content, "idx" : idx})
# Out:
# 100%|██████████| 22/22 [00:20<00:00,  1.09it/s]

# %%
question_context_pairs[0]
# Out:
# {'question': 'What are the two main announcements made by LangChain on June 27, 2024, as described in the provided context?',
#  'context': 'Announcing LangGraph v0.1 & LangGraph Cloud: Running agents at scale, reliably\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSkip to content\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nBy LangChain\n\n\n\n\nRelease Notes\n\n\n\n\nCase Studies\n\n\n\n\nLangChain\n\n\n\n\nGitHub\n\n\n\n\nDocs\n\n\n\n\n\nSign in\nSubscribe\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nAnnouncing LangGraph v0.1 & LangGraph Cloud: Running agents at scale, reliably\nOur new infrastructure for running agents at scale, LangGraph Cloud, is available in beta. We also have a new stable release of LangGraph.\n\n6 min read\nJun 27, 2024',
#  'idx': 0}

# %% [markdown]
# We'll repeat this process for answers!

# %%
answer_prompt_template = """\
You are a University Professor creating an exam. You must create a answer for a given piece of context and question.

The answer must only rely on the provided context.

Your output must only be the answer.

Context:
{context}
"""

answer_prompt = ChatPromptTemplate.from_template(answer_prompt_template)

# %%
answer_chain = answer_prompt | question_model

# %%
for question_context_pair in tqdm(question_context_pairs):
  question_context_pair["answer"] = answer_chain.invoke({"question" : question_context_pair["question"], "context" : question_context_pair["context"]}).content
# Out:
# 100%|██████████| 22/22 [00:18<00:00,  1.20it/s]

# %%
question_context_pairs[0]
# Out:
# {'question': 'What are the two main announcements made by LangChain on June 27, 2024, as described in the provided context?',
#  'context': 'Announcing LangGraph v0.1 & LangGraph Cloud: Running agents at scale, reliably\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSkip to content\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nBy LangChain\n\n\n\n\nRelease Notes\n\n\n\n\nCase Studies\n\n\n\n\nLangChain\n\n\n\n\nGitHub\n\n\n\n\nDocs\n\n\n\n\n\nSign in\nSubscribe\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nAnnouncing LangGraph v0.1 & LangGraph Cloud: Running agents at scale, reliably\nOur new infrastructure for running agents at scale, LangGraph Cloud, is available in beta. We also have a new stable release of LangGraph.\n\n6 min read\nJun 27, 2024',
#  'idx': 0,
#  'answer': 'LangGraph Cloud is available in what stage?\n\nBeta.'}

# %% [markdown]
# Now we can set up our LangSmith client - and we'll add the above created dataset to our LangSmith instance!
#
# > NOTE: Read more about this process [here](https://docs.smith.langchain.com/old/evaluation/faq/manage-datasets#create-from-list-of-values)

# %%
from langsmith import Client

client = Client()

dataset_name = "langsmith-demo-dataset-v1"

dataset = client.create_dataset(
    dataset_name=dataset_name, description="LangChain Blog Test Questions"
)

for triplet in question_context_pairs:
  client.create_example(
      inputs={"question" : triplet["question"]},
      outputs={"answer" : triplet["answer"]},
      dataset_id=dataset.id
  )

# %% [markdown]
# ### Evaluation
#
# Now we can run the evaluation!
#
# We'll need to start by preparing some custom data preparation functions to ensure our chain works with the expected inputs/outputs from the `evaluate` process in LangSmith.
#
# > NOTE: More reading on this available [here](https://docs.smith.langchain.com/how_to_guides/evaluation/evaluate_llm_application#evaluate-a-langchain-runnable)

# %%
def prepare_data_ref(run, example):
  return {
      "prediction" : run.outputs["response"],
      "reference" : example.outputs["answer"],
      "input" : example.inputs["question"]
  }

def prepare_data_noref(run, example):
  return {
      "prediction" : run.outputs["response"],
      "input" : example.inputs["question"]
  }

# %% [markdown]
# We'll be using a few custom evaluators to evaluate our pipeline, as well as a few "built in" methods!
#
# Check out the built-ins [here](https://docs.smith.langchain.com/reference/sdk_reference/langchain_evaluators)!

# %%
from langsmith.evaluation import LangChainStringEvaluator, evaluate

cot_qa_evaluator = LangChainStringEvaluator("cot_qa", prepare_data=prepare_data_ref)

unlabeled_dopeness_evaluator = LangChainStringEvaluator(
    "criteria",
    config={
        "criteria" : {
            "dopeness" : "Is the answer to the question dope, meaning cool - awesome - and legit?"
        }
    },
    prepare_data=prepare_data_noref
)

labeled_score_evaluator = LangChainStringEvaluator(
    "labeled_score_string",
    config={
        "criteria": {
            "accuracy": "Is the generated answer the same as the reference answer?"
        },
    },
    prepare_data=prepare_data_ref
)

unlabeled_coherence_evaluator = LangChainStringEvaluator("criteria", config={"criteria": "coherence"}, prepare_data=prepare_data_noref)
labeled_relevance_evaluator = LangChainStringEvaluator("labeled_criteria", config={ "criteria": "relevance"}, prepare_data=prepare_data_ref)

base_rag_results = evaluate(
    base_rag_chain.invoke,
    data=dataset_name,
    evaluators=[
        cot_qa_evaluator,
        unlabeled_dopeness_evaluator,
        labeled_score_evaluator,
        unlabeled_coherence_evaluator,
        labeled_relevance_evaluator
        ],
    experiment_prefix="Base RAG Evaluation"
)
# Out:
# View the evaluation results for experiment: 'Base RAG Evaluation-1377f308' at:
# https://smith.langchain.com/o/b4d209fb-759f-5d71-9114-4a80d4939b16/datasets/d7a0f358-f3d6-4763-9137-70795cfe39db/compare?selectedSessions=c0a53ecd-c67a-48f8-9f98-0ef5782f1e94
# 0it [00:00, ?it/s]
# Error running evaluator <DynamicRunEvaluator evaluate> on run fc9e632b-c91b-4acc-9235-bfb74a26d5bd: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9826, Requested 252. Please try again in 468ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/evaluation/scoring/eval_chain.py", line 352, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9826, Requested 252. Please try again in 468ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run 73d0225d-4827-4169-98cb-87565ec6fb61: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9837, Requested 243. Please try again in 480ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/evaluation/scoring/eval_chain.py", line 352, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9837, Requested 243. Please try again in 480ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run 25c2f3c6-5abb-4374-8cb9-4c91a475e268: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9791, Requested 288. Please try again in 474ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/evaluation/scoring/eval_chain.py", line 352, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9791, Requested 288. Please try again in 474ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run fb393156-d0ae-4697-8d41-c68beff76ef1: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9820, Requested 259. Please try again in 474ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/evaluation/scoring/eval_chain.py", line 352, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9820, Requested 259. Please try again in 474ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run 4b882176-aa07-4400-86f9-0c395829b5da: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9744, Requested 335. Please try again in 474ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/evaluation/scoring/eval_chain.py", line 352, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9744, Requested 335. Please try again in 474ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run 896e941b-795b-4deb-adda-809e15d1e7eb: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9726, Requested 348. Please try again in 444ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/evaluation/scoring/eval_chain.py", line 352, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9726, Requested 348. Please try again in 444ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run e883bacb-27dd-4af7-999c-45858b99c977: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9786, Requested 293. Please try again in 474ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/evaluation/scoring/eval_chain.py", line 352, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9786, Requested 293. Please try again in 474ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run 77bc11b5-ee14-40e8-9b9c-f7b85e580fc4: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9780, Requested 299. Please try again in 474ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...
#     self._generate_with_cache(
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9852, Requested 412. Please try again in 1.584s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run 811a2ed6-7102-4e71-9723-9b697addf74b: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9842, Requested 420. Please try again in 1.572s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/evaluation/criteria/eval_chain.py", line 447, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9842, Requested 420. Please try again in 1.572s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run b35d7171-9ef3-4d8d-b598-655d80b8a874: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9685, Requested 621. Please try again in 1.836s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/evaluation/scoring/eval_chain.py", line 352, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9685, Requested 621. Please try again in 1.836s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}

# %% [markdown]
# ## Testing Other Retrievers
#
# Now we can test our how changing our Retriever impacts our LangSmith evaluation!
#
# We'll build this simple qa_chain factory to create standardized qa_chains where the only different component will be the retriever.

# %%
def create_qa_chain(retriever):
  primary_qa_llm = ChatOpenAI(model_name="gpt-3.5-turbo", temperature=0)
  created_qa_chain = (
    {"context": itemgetter("question") | retriever,
     "question": itemgetter("question")
    }
    | RunnablePassthrough.assign(
        context=itemgetter("context")
      )
    | {
         "response": base_rag_prompt | primary_qa_llm,
         "context": itemgetter("context"),
      }
  )
  return created_qa_chain

# %% [markdown]
# ### Task 1: Parent Document Retriever
#
# One of the easier ways we can imagine improving a retriever is to embed our documents into small chunks, and then retrieve a significant amount of additional context that "surrounds" the found context.
#
# You can read more about this method [here](https://python.langchain.com/docs/modules/data_connection/retrievers/parent_document_retriever)!
#
# The basic outline of this retrieval method is as follows:
#
# 1. Obtain User Question
# 2. Retrieve child documents using Dense Vector Retrieval
# 3. Merge the child documents based on their parents. If they have the same parents - they become merged.
# 4. Replace the child documents with their respective parent documents from an in-memory-store.
# 5. Use the parent documents to augment generation.

# %%
from langchain.retrievers import ParentDocumentRetriever
from langchain.storage import InMemoryStore
from qdrant_client import QdrantClient
from qdrant_client.models import Distance, VectorParams

client = QdrantClient(":memory:")
client.create_collection(
    collection_name="split_parents",
    vectors_config=VectorParams(size=1536, distance=Distance.COSINE),
)

vectorstore = Qdrant(client, collection_name="split_parents", embeddings=base_embeddings_model)

store = InMemoryStore()

# %%
parent_document_retriever = ParentDocumentRetriever(
    vectorstore=vectorstore,
    docstore=store,
    child_splitter=RecursiveCharacterTextSplitter(chunk_size=400),
    parent_splitter=RecursiveCharacterTextSplitter(chunk_size=2000),
)

# %%
parent_document_retriever.add_documents(documents)

# %% [markdown]
# Let's create, test, and then evaluate our new chain!

# %%
parent_document_retriever_qa_chain = create_qa_chain(parent_document_retriever)

# %%
parent_document_retriever_qa_chain.invoke({"question" : "What is RAG?"})["response"].content
# Out:
# 'RAG stands for Retrieval Augmented Generation, which is a central paradigm in Large Language Model (LLM) application development. It involves connecting LLMs to external data sources to retrieve relevant documents based on a user query and generate an answer grounded in the retrieved context.'

# %% [markdown]
# #### Evaluating the Parent Document Retrieval Pipeline
#
# Now that we've created a new retriever - let's try evaluating it on the same dataset!

# %%
pdr_rag_results = evaluate(
    parent_document_retriever_qa_chain.invoke,
    data=dataset_name,
    evaluators=[
        cot_qa_evaluator,
        unlabeled_dopeness_evaluator,
        labeled_score_evaluator,
        unlabeled_coherence_evaluator,
        labeled_relevance_evaluator
        ],
    experiment_prefix="Parent Document Retrieval RAG Evaluation"
)
# Out:
# View the evaluation results for experiment: 'Parent Document Retrieval RAG Evaluation-30ba5c60' at:
# https://smith.langchain.com/o/b4d209fb-759f-5d71-9114-4a80d4939b16/datasets/d7a0f358-f3d6-4763-9137-70795cfe39db/compare?selectedSessions=1dd64b62-aed6-4e87-bda9-5f01ff3529d5
# 0it [00:00, ?it/s]
# Error running evaluator <DynamicRunEvaluator evaluate> on run caaa7b0f-e08d-431e-871b-32726e68f766: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9985, Requested 353. Please try again in 2.027s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/evaluation/criteria/eval_chain.py", line 447, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9985, Requested 353. Please try again in 2.027s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run 817d5203-9c8e-4ca9-a8c8-fd87b1b4741d: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9978, Requested 358. Please try again in 2.015s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/evaluation/criteria/eval_chain.py", line 447, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9978, Requested 358. Please try again in 2.015s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run 2a4970f0-a24c-42fc-85fb-5b25ff82d86d: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9949, Requested 388. Please try again in 2.022s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/evaluation/criteria/eval_chain.py", line 447, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9949, Requested 388. Please try again in 2.022s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run 0039a98d-e07d-46c0-bb05-5e2301b121a2: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9661, Requested 406. Please try again in 402ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/evaluation/criteria/eval_chain.py", line 447, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9661, Requested 406. Please try again in 402ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run b16466ed-0db3-4ea8-8105-6239d18edfd2: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9647, Requested 421. Please try again in 408ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/evaluation/criteria/eval_chain.py", line 447, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9647, Requested 421. Please try again in 408ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run 947b479a-430c-4f61-b73f-98c93fdccc1f: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9964, Requested 465. Please try again in 2.574s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/evaluation/criteria/eval_chain.py", line 447, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9964, Requested 465. Please try again in 2.574s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run 2a4970f0-a24c-42fc-85fb-5b25ff82d86d: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9914, Requested 423. Please try again in 2.022s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/evaluation/scoring/eval_chain.py", line 352, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9914, Requested 423. Please try again in 2.022s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run caaa7b0f-e08d-431e-871b-32726e68f766: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9913, Requested 423. Please try again in 2.015s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...
#     self._generate_with_cache(
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9718, Requested 682. Please try again in 2.4s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run c7e7089c-3573-4119-bc65-670f90be4c80: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9974, Requested 386. Please try again in 2.16s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/evaluation/criteria/eval_chain.py", line 447, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9974, Requested 386. Please try again in 2.16s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run 77981642-a9dd-47b4-9e06-44b2792b9565: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9687, Requested 744. Please try again in 2.586s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/evaluation/scoring/eval_chain.py", line 352, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9687, Requested 744. Please try again in 2.586s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}

# %% [markdown]
# ### Task 2: Ensemble Retrieval
#
# Next let's look at ensemble retrieval!
#
# You can read more about this [here](https://python.langchain.com/docs/modules/data_connection/retrievers/ensemble)!
#
# The basic idea is as follows:
#
# 1. Obtain User Question
# 2. Hit the Retriever Pair
#     - Retrieve Documents with BM25 Sparse Vector Retrieval
#     - Retrieve Documents with Dense Vector Retrieval Method
# 3. Collect and "fuse" the retrieved docs based on their weighting using the [Reciprocal Rank Fusion](https://plg.uwaterloo.ca/~gvcormac/cormacksigir09-rrf.pdf) algorithm into a single ranked list.
# 4. Use those documents to augment our generation.
#
# Ensure your `weights` list - the relative weighting of each retriever - sums to 1!

# %%
# !pip install -q -U rank_bm25

# %%
from langchain.retrievers import BM25Retriever, EnsembleRetriever

text_splitter = RecursiveCharacterTextSplitter(chunk_size=450, chunk_overlap=75)
split_documents = text_splitter.split_documents(documents)

bm25_retriever = BM25Retriever.from_documents(split_documents)
bm25_retriever.k = 2

embedding = OpenAIEmbeddings()
vectorstore = Qdrant.from_documents(split_documents, embedding, location=":memory:")
qdrant_retriever = vectorstore.as_retriever(search_kwargs={"k": 3})

ensemble_retriever = EnsembleRetriever(
    retrievers=[
        bm25_retriever,
        qdrant_retriever
    ],
    weights=[
        0.5,
        0.5
    ])

# %%
ensemble_retriever_qa_chain = create_qa_chain(ensemble_retriever)

# %%
ensemble_retriever_qa_chain.invoke({"question" : "What is RAG?"})["response"].content
# Out:
# 'RAG stands for Retrieval Augmented Generation, which is a central paradigm in LLM (Large Language Models) application development. It involves connecting LLMs to external data sources to address the lack of recent or private information in the models.'

# %%
pdr_rag_results = evaluate(
    ensemble_retriever_qa_chain.invoke,
    data=dataset_name,
    evaluators=[
        cot_qa_evaluator,
        unlabeled_dopeness_evaluator,
        labeled_score_evaluator,
        unlabeled_coherence_evaluator,
        labeled_relevance_evaluator
        ],
    experiment_prefix="Hybrid Retrieval RAG Evaluation"
)
# Out:
# View the evaluation results for experiment: 'Hybrid Retrieval RAG Evaluation-b0c2d22a' at:
# https://smith.langchain.com/o/b4d209fb-759f-5d71-9114-4a80d4939b16/datasets/d7a0f358-f3d6-4763-9137-70795cfe39db/compare?selectedSessions=99e5c071-c9a7-4c3d-997d-a4ca4ec6bffd
# 0it [00:00, ?it/s]
# Error running evaluator <DynamicRunEvaluator evaluate> on run dbd64b57-839e-4c3f-9c39-2221c0b944b6: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9971, Requested 344. Please try again in 1.89s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/evaluation/criteria/eval_chain.py", line 447, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9971, Requested 344. Please try again in 1.89s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run 5c405e0c-fb7a-45dc-9add-d0940c0afe8f: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9955, Requested 361. Please try again in 1.896s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/evaluation/criteria/eval_chain.py", line 447, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9955, Requested 361. Please try again in 1.896s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run 6821f2bb-3684-4042-b70a-4a712989cde6: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9910, Requested 451. Please try again in 2.166s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/evaluation/criteria/eval_chain.py", line 447, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9910, Requested 451. Please try again in 2.166s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run a34b8b76-0557-4e91-aef2-e5e748ab7932: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9949, Requested 414. Please try again in 2.178s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/evaluation/criteria/eval_chain.py", line 447, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9949, Requested 414. Please try again in 2.178s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run f05533c9-3cb4-407d-8ab0-f0c02e1ad80f: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9962, Requested 396. Please try again in 2.148s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/evaluation/criteria/eval_chain.py", line 447, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9962, Requested 396. Please try again in 2.148s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run a4870e26-0446-49c0-ae9f-ef24b087ba05: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9949, Requested 413. Please try again in 2.172s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/evaluation/criteria/eval_chain.py", line 447, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9949, Requested 413. Please try again in 2.172s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run fe4dd010-395f-498e-87b8-6b1aa7110fc4: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9940, Requested 421. Please try again in 2.166s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/evaluation/criteria/eval_chain.py", line 447, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9940, Requested 421. Please try again in 2.166s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run 7913bbfa-afda-4a99-8ec4-00df3b15a4a4: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9948, Requested 413. Please try again in 2.166s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...
#     self._generate_with_cache(
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9734, Requested 435. Please try again in 1.013s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run 2ba3b549-dcbe-49cb-bde7-df7049f77727: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9623, Requested 423. Please try again in 276ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/evaluation/criteria/eval_chain.py", line 447, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9623, Requested 423. Please try again in 276ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run eb4bda86-e92a-49fc-a17f-1ee1446649c5: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9494, Requested 550. Please try again in 264ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/evaluation/criteria/eval_chain.py", line 447, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/Users/mickkhaw/anaconda3/envs/llmops-course/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-5Z7RzzV39K8KETCX8ZueQ6fP on tokens per min (TPM): Limit 10000, Used 9494, Requested 550. Please try again in 264ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}

# %% [markdown]
# #### ❓Question #1:
#
# What conclusions can you draw about the above results?
#
# **ANSWER:**
#
# Screenshot: https://capture.dropbox.com/RPckh4A5LZzTcwBN
#
# I would choose the parent doc retrieval (#2) for production use. Here's why:
#
# It has the highest contextual accuracy, which is crucial for ensuring the generated content is factually correct and aligned with the input context.
# While it scores lower on dopeness and relevance, the differences are not drastically large. The better contextual accuracy outweighs these slight deficits.
# It has equal coherence vs other methods, ensuring the output remains well-structured and logical. Its string accuracy, while not the highest, is still competitive.
#
# The parent approach seems to strike the best balance between accuracy and other metrics. It appears to be more conservative (less dope) but more precise in its responses, which is often preferable in production environments where factual correctness is important.
#
# Caveat: Small evaluation sample sizes due to token rate limits. Ideally we'd have a larger experiment dataset to better evaluate the 3 methods.
